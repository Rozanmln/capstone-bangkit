# %% [markdown]
# #Import Packages

# %%
import re 
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Read Data

# %% [markdown]
# ## Symptoms

# %%
symptoms = pd.read_csv('/content/drive/MyDrive/CapstoneProjectBangkitMachineLearning/Data/dataset.csv')
symptoms.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %% [markdown]
# ## Symptom Severity

# %%
severity = pd.read_csv('/content/drive/MyDrive/CapstoneProjectBangkitMachineLearning/Data/Symptom-severity.csv')
severity.head()
# Out:
#                 Symptom  weight
# 0               itching       1
# 1             skin_rash       3
# 2  nodal_skin_eruptions       4
# 3   continuous_sneezing       4
# 4             shivering       5

# %% [markdown]
# ## Disease Description

# %%
description = pd.read_csv('/content/drive/MyDrive/CapstoneProjectBangkitMachineLearning/Data/symptom_Description.csv')
description.head()
# Out:
#           Disease                                        Description
# 0   Drug Reaction  An adverse drug reaction (ADR) is an injury ca...
# 1         Malaria  An infectious disease caused by protozoan para...
# 2         Allergy  An allergy is an immune system response to a f...
# 3  Hypothyroidism  Hypothyroidism, also called underactive thyroi...
# 4       Psoriasis  Psoriasis is a common skin disorder that forms...

# %%
precaution = pd.read_csv('/content/drive/MyDrive/CapstoneProjectBangkitMachineLearning/Data/symptom_precaution.csv')
precaution.head()
# Out:
#           Disease                      Precaution_1  \
# 0   Drug Reaction                   stop irritation
# 1         Malaria          Consult nearest hospital
# 2         Allergy                    apply calamine
# 3  Hypothyroidism                     reduce stress
# 4       Psoriasis  wash hands with warm soapy water
#
#                    Precaution_2        Precaution_3  \
# 0      consult nearest hospital    stop taking drug
# 1               avoid oily food  avoid non veg food
# 2       cover area with bandage                 NaN
# 3                      exercise         eat healthy
# 4  stop bleeding using pressure      consult doctor
#
#                   Precaution_4
# 0                    follow up
# 1           keep mosquitos out
# 2  use ice to compress itching
# 3             get proper sleep
# 4                   salt baths

# %% [markdown]
# #Coba-coba Christophe

# %%
symptom_severity = pd.read_csv('/content/drive/MyDrive/CapstoneProjectBangkitMachineLearning/Data/Symptom-severity.csv')
symptom_severity
# Out:
#                   Symptom  weight
# 0                 itching       1
# 1               skin_rash       3
# 2    nodal_skin_eruptions       4
# 3     continuous_sneezing       4
# 4               shivering       5
# ..                    ...     ...
# 128    inflammatory_nails       2
# 129               blister       4
# 130  red_sore_around_nose       2
# 131     yellow_crust_ooze       3
# 132             prognosis       5
#
# [133 rows x 2 columns]

# %%
dataset = pd.read_csv('/content/drive/MyDrive/CapstoneProjectBangkitMachineLearning/Data/dataset.csv')
dataset.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
print(dataset.dtypes)
# Out:
# Disease       object
# Symptom_1     object
# Symptom_2     object
# Symptom_3     object
# Symptom_4     object
# Symptom_5     object
# Symptom_6     object
# Symptom_7     object
# Symptom_8     object
# Symptom_9     object
# Symptom_10    object
# Symptom_11    object
# Symptom_12    object
# Symptom_13    object
# Symptom_14    object
# Symptom_15    object
# Symptom_16    object
# Symptom_17    object
# dtype: object

# %%
# Mengganti spaces dengan "_" dan menghapus spaces di bagian kiri kanan string
def substitute_spaces(string):
  if isinstance(string, str):
    string = string.strip()
    string = re.sub(" ","_",string)
  return string

# %%
for cols in dataset.columns:
  dataset[cols] = dataset[cols].apply(substitute_spaces)

# %%
dataset['Disease'].value_counts()
# Out:
# Fungal_infection                           120
# Hepatitis_C                                120
# Hepatitis_E                                120
# Alcoholic_hepatitis                        120
# Tuberculosis                               120
# Common_Cold                                120
# Pneumonia                                  120
# Dimorphic_hemmorhoids(piles)               120
# Heart_attack                               120
# Varicose_veins                             120
# Hypothyroidism                             120
# Hyperthyroidism                            120
# Hypoglycemia                               120
# Osteoarthristis                            120
# Arthritis                                  120
# (vertigo)_Paroymsal__Positional_Vertigo    120
# Acne                                       120
# Urinary_tract_infection                    120
# Psoriasis                                  120
# Hepatitis_D                                120
# ...

# %%
# Menggabungkan 17 kolom symptom menjadi 1 kolom dengan format list
cols = ['Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4', 'Symptom_5', 
        'Symptom_6', 'Symptom_7', 'Symptom_8', 'Symptom_9', 'Symptom_10', 
        'Symptom_11', 'Symptom_12', 'Symptom_13', 'Symptom_14', 'Symptom_15', 
        'Symptom_16', 'Symptom_17']
dataset['Symptom'] = dataset[cols].apply(lambda row: row.dropna().tolist(), axis=1)

# Drop kolom Symptom 1-17
dataset = dataset.drop(columns=cols)

# %%
dataset.sort_values('Disease', ascending=False)
# Out:
#                                       Disease  \
# 1014                              hepatitis_A
# 1830                              hepatitis_A
# 3422                              hepatitis_A
# 3668                              hepatitis_A
# 2971                              hepatitis_A
# ...                                       ...
# 2418  (vertigo)_Paroymsal__Positional_Vertigo
# 2417  (vertigo)_Paroymsal__Positional_Vertigo
# 2416  (vertigo)_Paroymsal__Positional_Vertigo
# 1599  (vertigo)_Paroymsal__Positional_Vertigo
# 2865  (vertigo)_Paroymsal__Positional_Vertigo
#
#                                                 Symptom
# 1014  [joint_pain, vomiting, dark_urine, nausea, los...
# 1830  [joint_pain, vomiting, yellowish_skin, dark_ur...
# 3422  [joint_pain, vomiting, yellowish_skin, dark_ur...
# 3668  [joint_pain, vomiting, yellowish_skin, dark_ur...
# 2971  [joint_pain, vomiting, yellowish_skin, dark_ur...
# ...                                                 ...
# ...

# %%
dataset = dataset.groupby('Disease')['Symptom'].agg(lambda x: sum(x, [])).reset_index(name='Symptoms')
dataset
# Out:
#                                     Disease  \
# 0   (vertigo)_Paroymsal__Positional_Vertigo
# 1                                      AIDS
# 2                                      Acne
# 3                       Alcoholic_hepatitis
# 4                                   Allergy
# 5                                 Arthritis
# 6                          Bronchial_Asthma
# 7                      Cervical_spondylosis
# 8                               Chicken_pox
# 9                       Chronic_cholestasis
# 10                              Common_Cold
# 11                                   Dengue
# 12                                 Diabetes
# 13             Dimorphic_hemmorhoids(piles)
# 14                            Drug_Reaction
# 15                         Fungal_infection
# 16                                     GERD
# 17                          Gastroenteritis
# 18                             Heart_attack
# 19                              Hepatitis_B
# ...

# %%
dataset['Symptoms'].value_counts()

# %%
dataset['Symptom'] = dataset['Symptom'].apply(sorted)

# %%
dataset['Symptom'].value_counts()

# %%
symptom_description = pd.read_csv('/content/drive/MyDrive/CapstoneProjectBangkitMachineLearning/Data/symptom_Description.csv')
symptom_description.head()
# Out:
#           Disease                                        Description
# 0   Drug Reaction  An adverse drug reaction (ADR) is an injury ca...
# 1         Malaria  An infectious disease caused by protozoan para...
# 2         Allergy  An allergy is an immune system response to a f...
# 3  Hypothyroidism  Hypothyroidism, also called underactive thyroi...
# 4       Psoriasis  Psoriasis is a common skin disorder that forms...

# %%
symptom_precaution = pd.read_csv('/content/drive/MyDrive/CapstoneProjectBangkitMachineLearning/Data/symptom_precaution.csv')
symptom_precaution.head()
# Out:
#           Disease                      Precaution_1  \
# 0   Drug Reaction                   stop irritation
# 1         Malaria          Consult nearest hospital
# 2         Allergy                    apply calamine
# 3  Hypothyroidism                     reduce stress
# 4       Psoriasis  wash hands with warm soapy water
#
#                    Precaution_2        Precaution_3  \
# 0      consult nearest hospital    stop taking drug
# 1               avoid oily food  avoid non veg food
# 2       cover area with bandage                 NaN
# 3                      exercise         eat healthy
# 4  stop bleeding using pressure      consult doctor
#
#                   Precaution_4
# 0                    follow up
# 1           keep mosquitos out
# 2  use ice to compress itching
# 3             get proper sleep
# 4                   salt baths

# %%
# df = symptom_description.merge(symptom_precaution.merge(dataset, how='inner', on = 'Disease'), how='inner', on='Disease')
# df.head()

# %%
df.shape
# Out:
# (4560, 23)

# %%
# Null values
df.isnull().sum()
# Out:
# Disease            0
# Description        0
# Precaution_1       0
# Precaution_2       0
# Precaution_3     120
# Precaution_4     120
# Symptom_1          0
# Symptom_2          0
# Symptom_3          0
# Symptom_4        348
# Symptom_5       1128
# Symptom_6       1746
# Symptom_7       2412
# Symptom_8       2736
# Symptom_9       2988
# Symptom_10      3120
# Symptom_11      3366
# Symptom_12      3816
# Symptom_13      4056
# Symptom_14      4254
# Symptom_15      4320
# Symptom_16      4368
# Symptom_17      4488
# dtype: int64

# %%
print(df['Symptom_1'].unique())
# Out:
# ['itching' ' skin_rash' ' chills' ' vomiting' ' continuous_sneezing'
#  ' shivering' ' fatigue' ' weight_gain' ' joint_pain' ' stomach_pain'
#  ' acidity' ' neck_pain' ' headache' ' pus_filled_pimples' ' high_fever'
#  ' indigestion' ' back_pain' ' weakness_in_limbs' ' mood_swings'
#  ' burning_micturition' ' bladder_discomfort' ' cramps' ' muscle_wasting'
#  ' patches_in_throat' ' yellowish_skin' ' cough' ' breathlessness'
#  ' muscle_weakness' ' stiff_neck' ' sunken_eyes']

# %%
df[df['Disease'] == 'Common Cold']

# %%
df[df['Symptom_17'] == ' muscle_pain']

# %%
df.drop_duplicates()
df.shape
# Out:
# (4560, 23)
